# %% [markdown]
# ## **Messwerte**

# %%
import numpy as np

#Gemisch 1

Zeiten_1 = np.array([126.38, 128.53, 129.45]) #Durchlaufzeiten des Gemischs in s
Zeiten_1_fehler = np.ones(3)*500e-3

K_1 = 0.9431 #Viskosimeterkonstante des 1. Viskosimeters
K_1_Fehler = 0

ny = K_1 * Zeiten_1 #Kinematische Viskosität

print(f"v_1 = {np.mean(ny)} +/- {500e-3*K_1} m**2/s")
# Out:
# v_1 = 120.829972 +/- 0.47155 m**2/s

# %%
#Gemisch 2

Zeiten_2 = np.array([349.25, 343.29, 341.41]) #Durchlaufzeiten des Gemischs in s
Zeiten_2_fehler = np.ones(3)*500e-3

K_2 = 0.29979 #Viskosimeterkonstante des 2. Viskosimeters
K_2_Fehler = 0

ny = K_2 * Zeiten_2 #Kinematische Viskosität

print(f"v_2 = {np.mean(ny)} +/- {500e-3*K_2} m**2/s")
# Out:
# v_2 = 103.3226235 +/- 0.149895 m**2/s
